# %%
# -*- coding: utf-8 -*-
"""
# Advanced Econometrics
# Spring semester
# Lab 01: Undergraduate Econometrics
# Rafal Wozniak
"""

# %% [markdown]
# packages

# %%
import math as math
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
import statsmodels.stats.outliers_influence as smo

# %% [markdown]
# working directory

# %%
import os as os
os.getcwd()
os.chdir('C:/Users/ekate/Advanced Econometrics 2023/Lab 1')
os.getcwd()
# Out:
# 'C:\\Users\\ekate\\Advanced Econometrics 2023\\Lab 1'

# %% [markdown]
# Exercise 1<br>
# read the data

# %%
cps = pd.read_csv("cps_small.csv", sep=",")
print(cps)
# Out:
#           wage  educ  exper  female  black  white  midwest  south  west
# 0     2.030000    13      2       1      0      1        0      1     0
# 1     2.070000    12      7       0      0      1        1      0     0
# 2     2.120000    12     35       0      0      1        0      1     0
# 3     2.540000    16     20       1      0      1        0      1     0
# 4     2.680000    12     24       1      0      1        0      1     0
# ..         ...   ...    ...     ...    ...    ...      ...    ...   ...
# 995  35.419998    18     23       1      0      1        0      0     0
# 996  36.840000    16      7       1      0      1        1      0     0
# 997  41.320000    16     11       1      0      1        0      0     0
# 998  47.220001    18     35       0      0      1        0      0     0
# 999  60.189999    16     33       0      0      1        0      0     1
#
# [1000 rows x 9 columns]

# %% [markdown]
# generate lnWAGE

# %%
cps['lnWAGE'] = np.log(cps['wage'])
# generate the interaction term
cps['blackXfemale'] =cps['black']*cps['female']

# %% [markdown]
# model - version 1

# %%
reg = smf.ols(formula="lnWAGE~educ+female+black+blackXfemale", data=cps)
model1 = reg.fit()
print(model1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 lnWAGE   R-squared:                       0.273
# Model:                            OLS   Adj. R-squared:                  0.270
# Method:                 Least Squares   F-statistic:                     93.37
# Date:                Thu, 20 Feb 2025   Prob (F-statistic):           1.88e-67
# Time:                        00:21:27   Log-Likelihood:                -666.33
# No. Observations:                1000   AIC:                             1343.
# Df Residuals:                     995   BIC:                             1367.
# Df Model:                           4
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        0.9566      0.084     11.361      0.000       0.791       1.122
# educ             0.1016      0.006     16.745      0.000       0.090       0.113
# female          -0.2557      0.031     -8.170      0.000      -0.317      -0.194
# black           -0.1842      0.078     -2.363      0.018      -0.337      -0.031
# blackXfemale     0.0654      0.106      0.617      0.537      -0.142       0.273
# ==============================================================================
# Omnibus:                        1.642   Durbin-Watson:                   0.538
# Prob(Omnibus):                  0.440   Jarque-Bera (JB):                1.531
# Skew:                           0.091   Prob(JB):                        0.465
# Kurtosis:                       3.062   Cond. No.                         113.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# model - version 2

# %%
reg = smf.ols(formula="np.log(wage)~educ+female+black+black*female", data=cps)
model2 = reg.fit()
print(model2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           np.log(wage)   R-squared:                       0.273
# Model:                            OLS   Adj. R-squared:                  0.270
# Method:                 Least Squares   F-statistic:                     93.37
# Date:                Thu, 20 Feb 2025   Prob (F-statistic):           1.88e-67
# Time:                        00:21:33   Log-Likelihood:                -666.33
# No. Observations:                1000   AIC:                             1343.
# Df Residuals:                     995   BIC:                             1367.
# Df Model:                           4
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        0.9566      0.084     11.361      0.000       0.791       1.122
# educ             0.1016      0.006     16.745      0.000       0.090       0.113
# female          -0.2557      0.031     -8.170      0.000      -0.317      -0.194
# black           -0.1842      0.078     -2.363      0.018      -0.337      -0.031
# black:female     0.0654      0.106      0.617      0.537      -0.142       0.273
# ==============================================================================
# Omnibus:                        1.642   Durbin-Watson:                   0.538
# Prob(Omnibus):                  0.440   Jarque-Bera (JB):                1.531
# Skew:                           0.091   Prob(JB):                        0.465
# Kurtosis:                       3.062   Cond. No.                         113.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# model - version 3

# %%
reg = smf.ols(formula="np.log(wage)~educ+female+black+black:female", data=cps)
model3 = reg.fit()
print(model3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           np.log(wage)   R-squared:                       0.273
# Model:                            OLS   Adj. R-squared:                  0.270
# Method:                 Least Squares   F-statistic:                     93.37
# Date:                Thu, 20 Feb 2025   Prob (F-statistic):           1.88e-67
# Time:                        00:21:35   Log-Likelihood:                -666.33
# No. Observations:                1000   AIC:                             1343.
# Df Residuals:                     995   BIC:                             1367.
# Df Model:                           4
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        0.9566      0.084     11.361      0.000       0.791       1.122
# educ             0.1016      0.006     16.745      0.000       0.090       0.113
# female          -0.2557      0.031     -8.170      0.000      -0.317      -0.194
# black           -0.1842      0.078     -2.363      0.018      -0.337      -0.031
# black:female     0.0654      0.106      0.617      0.537      -0.142       0.273
# ==============================================================================
# Omnibus:                        1.642   Durbin-Watson:                   0.538
# Prob(Omnibus):                  0.440   Jarque-Bera (JB):                1.531
# Skew:                           0.091   Prob(JB):                        0.465
# Kurtosis:                       3.062   Cond. No.                         113.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Quality Publication Table

# %%
# !pip install stargazer
from stargazer.stargazer import Stargazer
# Out:
# Collecting stargazer
#   Downloading stargazer-0.0.7-py3-none-any.whl.metadata (6.3 kB)
# Downloading stargazer-0.0.7-py3-none-any.whl (15 kB)
# Installing collected packages: stargazer
# Successfully installed stargazer-0.0.7

# %%
s = Stargazer([model1, model2, model3])
from IPython.core.display import HTML
a = HTML(s.render_html())
html = a.data
with open("html_file_Exercise1.html", "w") as f:
    f.write(html)

# %% [markdown]
# Exercise 2

# %%
stockton = pd.read_csv("stockton2.csv", sep=",")
print(stockton)
# Out:
#       price  sqft  beds  baths  age  stories  vacant
# 0    205000  2377     4      3    0        2       1
# 1    230000  2325     4      3    0        2       1
# 2    117000  1651     3      2    9        2       1
# 3     80000  1213     3      1   63        1       0
# 4    116500  1800     4      2   17        1       0
# ..      ...   ...   ...    ...  ...      ...     ...
# 875  168000  2120     4      3    7        2       1
# 876  135000  1714     4      3    3        2       1
# 877  115000  1501     3      2   11        1       1
# 878  112000  1367     3      2   16        1       1
# 879   90300   976     2      2   15        1       1
#
# [880 rows x 7 columns]

# %% [markdown]
# model 1

# %%
reg = smf.ols(formula="np.log(price)~sqft+baths+vacant+stories", data=stockton)
model1 = reg.fit()
print(model1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          np.log(price)   R-squared:                       0.721
# Model:                            OLS   Adj. R-squared:                  0.720
# Method:                 Least Squares   F-statistic:                     565.7
# Date:                Thu, 20 Feb 2025   Prob (F-statistic):          7.31e-241
# Time:                        00:23:00   Log-Likelihood:                 173.51
# No. Observations:                 880   AIC:                            -337.0
# Df Residuals:                     875   BIC:                            -313.1
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     10.6598      0.026    411.965      0.000      10.609      10.711
# sqft           0.0006   1.98e-05     29.290      0.000       0.001       0.001
# baths          0.0387      0.017      2.325      0.020       0.006       0.071
# vacant        -0.0689      0.014     -5.037      0.000      -0.096      -0.042
# stories       -0.0690      0.022     -3.147      0.002      -0.112      -0.026
# ==============================================================================
# Omnibus:                       36.916   Durbin-Watson:                   1.147
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               69.577
# Skew:                           0.285   Prob(JB):                     7.79e-16
# Kurtosis:                       4.254   Cond. No.                     7.06e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.06e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# model 2

# %%
reg = smf.ols(formula="np.log(price)~sqft+sqft^2+baths+vacant+stories+vacant:stories", 
              data=stockton)
model2 = reg.fit()
print(model2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          np.log(price)   R-squared:                       0.721
# Model:                            OLS   Adj. R-squared:                  0.720
# Method:                 Least Squares   F-statistic:                     376.8
# Date:                Thu, 20 Feb 2025   Prob (F-statistic):          2.62e-238
# Time:                        00:23:02   Log-Likelihood:                 173.98
# No. Observations:                 880   AIC:                            -334.0
# Df Residuals:                     873   BIC:                            -300.5
# Df Model:                           6
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept         10.6789      0.033    325.126      0.000      10.614      10.743
# sqft               0.0002      0.003      0.056      0.955      -0.006       0.007
# sqft ^ 2           0.0004      0.003      0.115      0.908      -0.006       0.007
# baths              0.0379      0.017      2.273      0.023       0.005       0.071
# vacant            -0.1071      0.042     -2.531      0.012      -0.190      -0.024
# stories           -0.0852      0.028     -3.063      0.002      -0.140      -0.031
# vacant:stories     0.0317      0.033      0.954      0.340      -0.034       0.097
# ==============================================================================
# Omnibus:                       37.677   Durbin-Watson:                   1.153
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               71.234
# Skew:                           0.290   Prob(JB):                     3.40e-16
# Kurtosis:                       4.267   Cond. No.                     2.18e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.18e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# Exercise 3

# %%
data = pd.read_stata("http://www.principlesofeconometrics.com/poe3/data/stata/stockton.dta")

# %%
reg = smf.ols(formula="price~age+sqft", data=data)
model = reg.fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.544
# Model:                            OLS   Adj. R-squared:                  0.544
# Method:                 Least Squares   F-statistic:                     2796.
# Date:                Thu, 20 Feb 2025   Prob (F-statistic):               0.00
# Time:                        00:23:06   Log-Likelihood:                -53846.
# No. Observations:                4682   AIC:                         1.077e+05
# Df Residuals:                    4679   BIC:                         1.077e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.008e+04   1736.638      5.807      0.000    6680.207    1.35e+04
# age         -215.9495     17.920    -12.051      0.000    -251.081    -180.817
# sqft          72.3740      1.058     68.410      0.000      70.300      74.448
# ==============================================================================
# Omnibus:                     1144.596   Durbin-Watson:                   1.809
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6672.400
# Skew:                           1.038   Prob(JB):                         0.00
# Kurtosis:                       8.468   Cond. No.                     7.40e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.4e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# a) functional form validity<br>
# i. Ramsey's RESET test

# %%
resettest = smo.reset_ramsey(res=model, degree=3)
print(resettest.summary())
# albo po prostu
smo.reset_ramsey(res=model, degree=3)
# Out:
# <F test: F=10.413284949309995, p=3.073315577920865e-05, df_denom=4.68e+03, df_num=2>
# <class 'statsmodels.stats.contrast.ContrastResults'>
# <F test: F=10.413284949309995, p=3.073315577920865e-05, df_denom=4.68e+03, df_num=2>

# %% [markdown]
# type="regressor"

# %%
reg = smf.ols(formula="price~age+sqft+I(age**2)+I(sqft**2)+I(age**3)+I(sqft**3)+age:sqft", 
              data=data)
reset_regresor = reg.fit()
print(reset_regresor.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.551
# Model:                            OLS   Adj. R-squared:                  0.550
# Method:                 Least Squares   F-statistic:                     819.6
# Date:                Thu, 20 Feb 2025   Prob (F-statistic):               0.00
# Time:                        00:23:12   Log-Likelihood:                -53811.
# No. Observations:                4682   AIC:                         1.076e+05
# Df Residuals:                    4674   BIC:                         1.077e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept     5158.9196      2e+04      0.259      0.796    -3.4e+04    4.43e+04
# age           -124.4442    138.041     -0.902      0.367    -395.070     146.181
# sqft            77.2806     42.151      1.833      0.067      -5.354     159.916
# I(age ** 2)     12.3151      3.379      3.645      0.000       5.691      18.939
# I(sqft ** 2)    -0.0043      0.029     -0.146      0.884      -0.061       0.053
# I(age ** 3)     -0.1270      0.028     -4.577      0.000      -0.181      -0.073
# I(sqft ** 3)  2.203e-06   6.57e-06      0.335      0.738   -1.07e-05    1.51e-05
# age:sqft        -0.2535      0.053     -4.762      0.000      -0.358      -0.149
# ==============================================================================
# Omnibus:                     1137.609   Durbin-Watson:                   1.815
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6716.395
# Skew:                           1.027   Prob(JB):                         0.00
# Kurtosis:                       8.496   Cond. No.                     2.46e+11
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.46e+11. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# the corrected model

# %%
reg = smf.ols(formula="price~age+sqft+I(age**2)+I(age**3)+age:sqft", data=data)
model2 = reg.fit()
print(model2.summary())
smo.reset_ramsey(res=model2, degree=3)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.551
# Model:                            OLS   Adj. R-squared:                  0.550
# Method:                 Least Squares   F-statistic:                     1146.
# Date:                Thu, 20 Feb 2025   Prob (F-statistic):               0.00
# Time:                        00:23:13   Log-Likelihood:                -53813.
# No. Observations:                4682   AIC:                         1.076e+05
# Df Residuals:                    4676   BIC:                         1.077e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept   -1007.0530   2705.833     -0.372      0.710   -6311.762    4297.656
# age           -88.6721    136.383     -0.650      0.516    -356.047     178.703
# sqft           80.3484      1.688     47.596      0.000      77.039      83.658
# I(age ** 2)    12.4881      3.378      3.697      0.000       5.865      19.111
# I(age ** 3)    -0.1287      0.028     -4.640      0.000      -0.183      -0.074
# age:sqft       -0.2792      0.051     -5.491      0.000      -0.379      -0.180
# ==============================================================================
# Omnibus:                     1156.652   Durbin-Watson:                   1.814
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6840.885
# Skew:                           1.046   Prob(JB):                         0.00
# Kurtosis:                       8.540   Cond. No.                     9.92e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.92e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# <class 'statsmodels.stats.contrast.ContrastResults'>
# <F test: F=2.808280639385418, p=0.06041035853093531, df_denom=4.67e+03, df_num=2>

# %% [markdown]
# b) heteroskedasticity

# %%
reg = smf.ols(formula="price~age+sqft", data=data)
model = reg.fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.544
# Model:                            OLS   Adj. R-squared:                  0.544
# Method:                 Least Squares   F-statistic:                     2796.
# Date:                Thu, 20 Feb 2025   Prob (F-statistic):               0.00
# Time:                        00:23:14   Log-Likelihood:                -53846.
# No. Observations:                4682   AIC:                         1.077e+05
# Df Residuals:                    4679   BIC:                         1.077e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.008e+04   1736.638      5.807      0.000    6680.207    1.35e+04
# age         -215.9495     17.920    -12.051      0.000    -251.081    -180.817
# sqft          72.3740      1.058     68.410      0.000      70.300      74.448
# ==============================================================================
# Omnibus:                     1144.596   Durbin-Watson:                   1.809
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6672.400
# Skew:                           1.038   Prob(JB):                         0.00
# Kurtosis:                       8.468   Cond. No.                     7.40e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.4e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# i. Breusch-Pagan test<br>
# Conduct the Breusch-Pagan test

# %%
from statsmodels.compat import lzip
import statsmodels.stats.api as sms
names = ['Lagrange multiplier statistic', 'p-value',
         'f-value', 'f p-value']
# Get the test result
test_result = sms.het_breuschpagan(model.resid, model.model.exog)
lzip(names, test_result)
# Out:
# [('Lagrange multiplier statistic', np.float64(187.50540195850112)),
#  ('p-value', np.float64(1.9218491730420718e-41)),
#  ('f-value', np.float64(97.60138282801945)),
#  ('f p-value', np.float64(2.9689048654399586e-42))]

# %% [markdown]
# ii. White's test

# %%
X_white = pd.DataFrame({"const": 1, "fitted_reg": model.fittedvalues,
"fitted_reg_sq": model.fittedvalues ** 2})

# %%
result_white = sms.het_breuschpagan(model.resid, X_white)
white_statistic = result_white[0]
white_pval = result_white[1]
print(f"white_statistic: {white_statistic}\n")
print(f"white_pval: {white_pval}\n")
# Out:
# white_statistic: 181.53667125008434
#
# white_pval: 3.800254714888217e-40

# %% [markdown]
# c) normality of errors

# %%
import statsmodels.api as sm
name = ["Jarque-Bera test", "Chi^2 two-tail prob.", "Skew", "Kurtosis"]
test = sms.jarque_bera(model.resid)
lzip(name, test)
# However, we do not need this, because the basic output contains 
# the JB test results.
# Out:
# [('Jarque-Bera test', np.float64(6672.399676776623)),
#  ('Chi^2 two-tail prob.', np.float64(0.0)),
#  ('Skew', np.float64(1.0377048056801284)),
#  ('Kurtosis', np.float64(8.467677074975605))]

# %% [markdown]
# Exercise 4

# %%
budgets = pd.read_stata("budgets.dta")

# %% [markdown]
# model

# %%
reg = smf.ols(formula="alcohol~income+expend+location+nop+price", data=budgets)
model1 = reg.fit()
print(model1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                alcohol   R-squared:                       0.058
# Model:                            OLS   Adj. R-squared:                  0.058
# Method:                 Least Squares   F-statistic:                     219.5
# Date:                Thu, 20 Feb 2025   Prob (F-statistic):               0.00
# Time:                        00:27:25   Log-Likelihood:            -1.8461e+05
# No. Observations:               31847   AIC:                         3.692e+05
# Df Residuals:                   31837   BIC:                         3.693e+05
# Df Model:                           9
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept              -166.5540     29.762     -5.596      0.000    -224.889    -108.219
# location[T.200t-500t]     1.8613      1.784      1.043      0.297      -1.636       5.359
# location[T.100t-200t]    -1.4859      1.988     -0.748      0.455      -5.382       2.410
# location[T.20t-100t]     -1.7764      1.587     -1.119      0.263      -4.887       1.335
# location[T.-20t]         -5.4061      1.780     -3.038      0.002      -8.894      -1.918
# location[T.wies]          0.1012      1.505      0.067      0.946      -2.848       3.051
# income                    0.0066      0.000     16.736      0.000       0.006       0.007
# expend                    0.0075      0.000     17.544      0.000       0.007       0.008
# nop                       2.1764      0.311      7.007      0.000       1.568       2.785
# price                   163.6869     29.078      5.629      0.000     106.693     220.680
# ==============================================================================
# Omnibus:                    52490.154   Durbin-Watson:                   1.983
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        315717671.051
# Skew:                          10.208   Prob(JB):                         0.00
# Kurtosis:                     490.349   Cond. No.                     3.09e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.09e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# hypothesis testing using the t test<br>
# H0: beta_dochg = 0

# %%
hypothesis = ["income=0"]
model1.t_test(hypothesis)
# Out:
# <class 'statsmodels.stats.contrast.ContrastResults'>
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0066      0.000     16.736      0.000       0.006       0.007
# ==============================================================================

# %% [markdown]
# H0: beta_los = 2

# %%
hypothesis = ["nop=2"]
model1.t_test(hypothesis)
# Out:
# <class 'statsmodels.stats.contrast.ContrastResults'>
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             2.1764      0.311      0.568      0.570       1.568       2.785
# ==============================================================================

# %% [markdown]
# testing the hypothesis H0: beta_klm5 = -5

# %%
hypothesis = ["location[T.-20t]=-5"]
model1.t_test(hypothesis)
# Out:
# <class 'statsmodels.stats.contrast.ContrastResults'>
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0            -5.4061      1.780     -0.228      0.820      -8.894      -1.918
# ==============================================================================

# %% [markdown]
# hypothesis testing using the F test

# %%
hypothesis = ["location[T.200t-500t]=0", "location[T.100t-200t]=0", "location[T.20t-100t]=0",
              "location[T.-20t]=0", "location[T.wies]=0"]
model1.f_test(hypothesis)
# Out:
# <class 'statsmodels.stats.contrast.ContrastResults'>
# <F test: F=4.090957890683243, p=0.0010289466487598444, df_denom=3.18e+04, df_num=5>

# %% [markdown]
# Exercise 5

# %%
fertil = pd.read_csv("fertil2.csv")

# %% [markdown]
# a) the regression model

# %%
reg = smf.ols(formula='ceb ~ age+agefbrth+usemeth', data=fertil)
model = reg.fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    ceb   R-squared:                       0.573
# Model:                            OLS   Adj. R-squared:                  0.572
# Method:                 Least Squares   F-statistic:                     1433.
# Date:                Thu, 20 Feb 2025   Prob (F-statistic):               0.00
# Time:                        00:29:17   Log-Likelihood:                -5779.6
# No. Observations:                3213   AIC:                         1.157e+04
# Df Residuals:                    3209   BIC:                         1.159e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.3581      0.174      7.815      0.000       1.017       1.699
# age            0.2237      0.003     64.888      0.000       0.217       0.230
# agefbrth      -0.2607      0.009    -29.637      0.000      -0.278      -0.243
# usemeth        0.1874      0.055      3.380      0.001       0.079       0.296
# ==============================================================================
# Omnibus:                      160.051   Durbin-Watson:                   1.860
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              573.430
# Skew:                          -0.070   Prob(JB):                    3.03e-125
# Kurtosis:                       5.065   Cond. No.                         245.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# b) verify the homoscedasticity assumption with Breuschâ€™s and Paganâ€™s test

# %%
from statsmodels.compat import lzip
import statsmodels.stats.api as sms
names = ['Lagrange multiplier statistic', 'p-value',
         'f-value', 'f p-value']
# Get the test result
test_result = sms.het_breuschpagan(model.resid, model.model.exog)
lzip(names, test_result)
# Out:
# [('Lagrange multiplier statistic', np.float64(864.5019269133697)),
#  ('p-value', np.float64(4.432169009460693e-187)),
#  ('f-value', np.float64(393.75331199355145)),
#  ('f p-value', np.float64(9.228919722589057e-218))]

# %% [markdown]
# c) apply Whiteâ€™s robust estimator (Whiteâ€™s-Huberâ€™s)

# %%
reg = smf.ols(formula='ceb ~ age+agefbrth+usemeth', data=fertil)
model_HC0 = reg.fit(cov_type="HC0")
print(model_HC0.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    ceb   R-squared:                       0.573
# Model:                            OLS   Adj. R-squared:                  0.572
# Method:                 Least Squares   F-statistic:                     875.2
# Date:                Thu, 20 Feb 2025   Prob (F-statistic):               0.00
# Time:                        00:29:25   Log-Likelihood:                -5779.6
# No. Observations:                3213   AIC:                         1.157e+04
# Df Residuals:                    3209   BIC:                         1.159e+04
# Df Model:                           3
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.3581      0.167      8.110      0.000       1.030       1.686
# age            0.2237      0.005     48.022      0.000       0.215       0.233
# agefbrth      -0.2607      0.010    -27.278      0.000      -0.279      -0.242
# usemeth        0.1874      0.061      3.092      0.002       0.069       0.306
# ==============================================================================
# Omnibus:                      160.051   Durbin-Watson:                   1.860
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              573.430
# Skew:                          -0.070   Prob(JB):                    3.03e-125
# Kurtosis:                       5.065   Cond. No.                         245.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)

# %% [markdown]
# d) apply Whiteâ€™s robust estimator MacKinnonâ€™s and Whiteâ€™s

# %%
reg = smf.ols(formula='ceb ~ age+agefbrth+usemeth', data=fertil)
model_HC3 = reg.fit(cov_type="HC3")
print(model_HC3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    ceb   R-squared:                       0.573
# Model:                            OLS   Adj. R-squared:                  0.572
# Method:                 Least Squares   F-statistic:                     871.5
# Date:                Thu, 20 Feb 2025   Prob (F-statistic):               0.00
# Time:                        00:29:27   Log-Likelihood:                -5779.6
# No. Observations:                3213   AIC:                         1.157e+04
# Df Residuals:                    3209   BIC:                         1.159e+04
# Df Model:                           3
# Covariance Type:                  HC3
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.3581      0.168      8.088      0.000       1.029       1.687
# age            0.2237      0.005     47.914      0.000       0.215       0.233
# agefbrth      -0.2607      0.010    -27.198      0.000      -0.279      -0.242
# usemeth        0.1874      0.061      3.086      0.002       0.068       0.306
# ==============================================================================
# Omnibus:                      160.051   Durbin-Watson:                   1.860
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              573.430
# Skew:                          -0.070   Prob(JB):                    3.03e-125
# Kurtosis:                       5.065   Cond. No.                         245.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)

# %% [markdown]
# e) assume that there are clusters in our data <br>
# (children â€“ number of children in the household);<br>
# apply appropriate robust matrix

# %% [markdown]
# drop NAs

# %%
fertil_clstrd = fertil[["ceb","age","agefbrth","usemeth","children"]]
fertil_clstrd = fertil_clstrd.dropna()

# %%
reg = smf.ols(formula='ceb ~ age+agefbrth+usemeth', data=fertil_clstrd)
model_clstrd = reg.fit(cov_type="cluster", cov_kwds = {"groups":fertil_clstrd["children"]})
print(model_clstrd.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    ceb   R-squared:                       0.573
# Model:                            OLS   Adj. R-squared:                  0.572
# Method:                 Least Squares   F-statistic:                     20.91
# Date:                Thu, 20 Feb 2025   Prob (F-statistic):           2.97e-05
# Time:                        00:29:32   Log-Likelihood:                -5779.6
# No. Observations:                3213   AIC:                         1.157e+04
# Df Residuals:                    3209   BIC:                         1.159e+04
# Df Model:                           3
# Covariance Type:              cluster
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.3581      0.425      3.197      0.001       0.525       2.191
# age            0.2237      0.032      7.101      0.000       0.162       0.285
# agefbrth      -0.2607      0.035     -7.357      0.000      -0.330      -0.191
# usemeth        0.1874      0.094      1.986      0.047       0.002       0.372
# ==============================================================================
# Omnibus:                      160.051   Durbin-Watson:                   1.860
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              573.430
# Skew:                          -0.070   Prob(JB):                    3.03e-125
# Kurtosis:                       5.065   Cond. No.                         245.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)

# %% [markdown]
# f) present results from (a), (c), (d), and (e) in one Quality Publication Table

# %%
from stargazer.stargazer import Stargazer
